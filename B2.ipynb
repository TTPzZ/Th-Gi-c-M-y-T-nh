# %%
from PIL import Image
from imgtools import *

# %%
my_dir = r'C:\\Users\\Phuc\\TGMTLop6\\imgae'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# (224, 224)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# (259, 195)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x195>
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
display(my_dir)
print (my_dir)
# Out:
# 'C:\\\\Users\\\\Phuc\\\\TGMTLop6\\\\imgae'
# C:\\Users\\Phuc\\TGMTLop6\\imgae
