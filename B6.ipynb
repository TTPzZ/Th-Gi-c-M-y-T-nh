# %%
from PIL import Image
from imgtools import *

# %%
my_path='C:/Users/Phuc/TGMTLop6/imgae/he.jpg'
img = load_image(my_path)
thumbnail_size=(400,400)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=400x225>

# %%
# chuyển ảnh thành màu xám
gray_image=img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=400x225>

# %%
red, green, blue = img.split()
display(red)
display(green)
display(blue)
# Out:
# <PIL.Image.Image image mode=L size=400x225>
# <PIL.Image.Image image mode=L size=400x225>
# <PIL.Image.Image image mode=L size=400x225>

# %%
merged_img = Image.merge("RGB",(red,green,blue))
display(merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x225>

# %%
merged_img = Image.merge("RGB",(green,red,blue))
display(merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x225>

# %%
merged_img = Image.merge("RGB",(red,red,blue))
display(merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x225>
