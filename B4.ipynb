# %%
from PIL import Image
from imgtools import *

# %%
my_path='C:/Users/Phuc/TGMTLop6/imgae/6.png'
img = load_image(my_path)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x195>

# %%
# Định vị khu vực cắt
region = (100, 75, 175, 100)
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=P size=75x25>

# %%
paste_position = (150,150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x195>
