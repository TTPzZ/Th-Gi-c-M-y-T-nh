# %%
from PIL import Image
from imgtools import *

# %%
my_path='C:/Users/Phuc/TGMTLop6/imgae/6.png'
img = load_image(my_path)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x195>

# %%
#xoay ảnh 
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=259x195>

# %%
# vẫn là xoay nhưng xịn hơn
transposed_image= img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=P size=195x259>
